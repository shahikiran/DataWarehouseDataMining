# %% [markdown]
# <a href="https://colab.research.google.com/github/1kalyan/DataWarehouseDataMining/blob/main/Lab1/Lab1_DWDM.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Each csv

import requests
import csv
import time

def fetch_stock_data(symbol, from_date, to_date, items_per_page=50):
    url = "https://www.nepalipaisa.com/api/GetStockHistory"
    page_no = 1
    all_data = []

    while True:
        params = {
            "stockSymbol": symbol,
            "fromDate": from_date,
            "toDate": to_date,
            "pageNo": page_no,
            "itemsPerPage": items_per_page,
            "pagePerDisplay": 10
        }

        response = requests.get(url, params=params)
        print(f"Fetching {symbol}, page {page_no} | Status: {response.status_code}")
        if response.status_code != 200:
            print(f"Failed to fetch data for {symbol}: HTTP {response.status_code}")
            break

        data = response.json()
        # Adjust this according to actual API response structure
        stock_data = data.get('result', {}).get('data', [])

        if not stock_data:
            print(f"No more data found for {symbol} at page {page_no}.")
            break  # No more data

        all_data.extend(stock_data)
        print(f"Fetched page {page_no} with {len(stock_data)} records for {symbol}")

        page_no += 1
        time.sleep(0.5)  # small delay to avoid rate limiting

    if all_data:
        keys = all_data[0].keys()
        filename = f"{symbol}.csv"
        with open(filename, 'w', newline='', encoding='utf-8') as f:
            writer = csv.DictWriter(f, fieldnames=keys)
            writer.writeheader()
            writer.writerows(all_data)
        print(f"Data for {symbol} saved to {filename}")
    else:
        print(f"No data found for {symbol}")

if __name__ == "__main__":
    symbols = ["ADBL", "NABIL", "NICA", "NMB", "SBL", "LSL", "KBL", "NBL", "PRVU", "HDL"]
    from_date = "2020-01-01"
    to_date = "2025-05-19"

    for symbol in symbols:
        fetch_stock_data(symbol, from_date, to_date)
# Out:
# Fetching ADBL, page 1 | Status: 200
# Fetched page 1 with 50 records for ADBL
# Fetching ADBL, page 2 | Status: 200
# Fetched page 2 with 50 records for ADBL
# Fetching ADBL, page 3 | Status: 200
# Fetched page 3 with 50 records for ADBL
# Fetching ADBL, page 4 | Status: 200
# Fetched page 4 with 50 records for ADBL
# Fetching ADBL, page 5 | Status: 200
# Fetched page 5 with 50 records for ADBL
# Fetching ADBL, page 6 | Status: 200
# Fetched page 6 with 50 records for ADBL
# Fetching ADBL, page 7 | Status: 200
# Fetched page 7 with 50 records for ADBL
# Fetching ADBL, page 8 | Status: 200
# Fetched page 8 with 50 records for ADBL
# Fetching ADBL, page 9 | Status: 200
# Fetched page 9 with 50 records for ADBL
# Fetching ADBL, page 10 | Status: 200
# Fetched page 10 with 50 records for ADBL
# Fetching ADBL, page 11 | Status: 200
# Fetched page 11 with 50 records for ADBL
# Fetching ADBL, page 12 | Status: 200
# Fetched page 12 with 50 records for ADBL
# Fetching ADBL, page 13 | Status: 200
# Fetched page 13 with 50 records for ADBL
# Fetching ADBL, page 14 | Status: 200
# Fetched page 14 with 50 records for ADBL
# Fetching ADBL, page 15 | Status: 200
# Fetched page 15 with 50 records for ADBL
# Fetching ADBL, page 16 | Status: 200
# Fetched page 16 with 50 records for ADBL
# Fetching ADBL, page 17 | Status: 200
# Fetched page 17 with 50 records for ADBL
# Fetching ADBL, page 18 | Status: 200
# Fetched page 18 with 50 records for ADBL
# Fetching ADBL, page 19 | Status: 200
# Fetched page 19 with 50 records for ADBL
# Fetching ADBL, page 20 | Status: 200
# Fetched page 20 with 50 records for ADBL
# Fetching ADBL, page 21 | Status: 200
# Fetched page 21 with 50 records for ADBL
# Fetching ADBL, page 22 | Status: 200
# Fetched page 22 with 50 records for ADBL
# Fetching ADBL, page 23 | Status: 200
# Fetched page 23 with 50 records for ADBL
# Fetching ADBL, page 24 | Status: 200
# Fetched page 24 with 50 records for ADBL
# Fetching ADBL, page 25 | Status: 200
# Fetched page 25 with 3 records for ADBL
# Fetching ADBL, page 26 | Status: 200
# No more data found for ADBL at page 26.
# Data for ADBL saved to ADBL.csv
# Fetching NABIL, page 1 | Status: 200
# Fetched page 1 with 50 records for NABIL
# Fetching NABIL, page 2 | Status: 200
# Fetched page 2 with 50 records for NABIL
# Fetching NABIL, page 3 | Status: 200
# Fetched page 3 with 50 records for NABIL
# Fetching NABIL, page 4 | Status: 200
# Fetched page 4 with 50 records for NABIL
# Fetching NABIL, page 5 | Status: 200
# Fetched page 5 with 50 records for NABIL
# Fetching NABIL, page 6 | Status: 200
# Fetched page 6 with 50 records for NABIL
# Fetching NABIL, page 7 | Status: 200
# Fetched page 7 with 50 records for NABIL
# Fetching NABIL, page 8 | Status: 200
# Fetched page 8 with 50 records for NABIL
# Fetching NABIL, page 9 | Status: 200
# Fetched page 9 with 50 records for NABIL
# Fetching NABIL, page 10 | Status: 200
# Fetched page 10 with 50 records for NABIL
# Fetching NABIL, page 11 | Status: 200
# Fetched page 11 with 50 records for NABIL
# Fetching NABIL, page 12 | Status: 200
# Fetched page 12 with 50 records for NABIL
# Fetching NABIL, page 13 | Status: 200
# Fetched page 13 with 50 records for NABIL
# Fetching NABIL, page 14 | Status: 200
# Fetched page 14 with 50 records for NABIL
# Fetching NABIL, page 15 | Status: 200
# Fetched page 15 with 50 records for NABIL
# Fetching NABIL, page 16 | Status: 200
# Fetched page 16 with 50 records for NABIL
# Fetching NABIL, page 17 | Status: 200
# Fetched page 17 with 50 records for NABIL
# Fetching NABIL, page 18 | Status: 200
# Fetched page 18 with 50 records for NABIL
# Fetching NABIL, page 19 | Status: 200
# Fetched page 19 with 50 records for NABIL
# Fetching NABIL, page 20 | Status: 200
# Fetched page 20 with 50 records for NABIL
# Fetching NABIL, page 21 | Status: 200
# Fetched page 21 with 50 records for NABIL
# Fetching NABIL, page 22 | Status: 200
# Fetched page 22 with 50 records for NABIL
# Fetching NABIL, page 23 | Status: 200
# Fetched page 23 with 50 records for NABIL
# Fetching NABIL, page 24 | Status: 200
# Fetched page 24 with 50 records for NABIL
# Fetching NABIL, page 25 | Status: 200
# Fetched page 25 with 2 records for NABIL
# Fetching NABIL, page 26 | Status: 200
# No more data found for NABIL at page 26.
# Data for NABIL saved to NABIL.csv
# Fetching NICA, page 1 | Status: 200
# Fetched page 1 with 50 records for NICA
# Fetching NICA, page 2 | Status: 200
# Fetched page 2 with 50 records for NICA
# Fetching NICA, page 3 | Status: 200
# Fetched page 3 with 50 records for NICA
# Fetching NICA, page 4 | Status: 200
# Fetched page 4 with 50 records for NICA
# Fetching NICA, page 5 | Status: 200
# Fetched page 5 with 50 records for NICA
# Fetching NICA, page 6 | Status: 200
# Fetched page 6 with 50 records for NICA
# Fetching NICA, page 7 | Status: 200
# Fetched page 7 with 50 records for NICA
# Fetching NICA, page 8 | Status: 200
# Fetched page 8 with 50 records for NICA
# Fetching NICA, page 9 | Status: 200
# Fetched page 9 with 50 records for NICA
# Fetching NICA, page 10 | Status: 200
# Fetched page 10 with 50 records for NICA
# Fetching NICA, page 11 | Status: 200
# Fetched page 11 with 50 records for NICA
# Fetching NICA, page 12 | Status: 200
# Fetched page 12 with 50 records for NICA
# Fetching NICA, page 13 | Status: 200
# Fetched page 13 with 50 records for NICA
# Fetching NICA, page 14 | Status: 200
# Fetched page 14 with 50 records for NICA
# Fetching NICA, page 15 | Status: 200
# Fetched page 15 with 50 records for NICA
# Fetching NICA, page 16 | Status: 200
# Fetched page 16 with 50 records for NICA
# Fetching NICA, page 17 | Status: 200
# Fetched page 17 with 50 records for NICA
# Fetching NICA, page 18 | Status: 200
# Fetched page 18 with 50 records for NICA
# Fetching NICA, page 19 | Status: 200
# Fetched page 19 with 50 records for NICA
# Fetching NICA, page 20 | Status: 200
# Fetched page 20 with 50 records for NICA
# Fetching NICA, page 21 | Status: 200
# Fetched page 21 with 50 records for NICA
# Fetching NICA, page 22 | Status: 200
# Fetched page 22 with 50 records for NICA
# Fetching NICA, page 23 | Status: 200
# Fetched page 23 with 50 records for NICA
# Fetching NICA, page 24 | Status: 200
# Fetched page 24 with 50 records for NICA
# Fetching NICA, page 25 | Status: 200
# Fetched page 25 with 1 records for NICA
# Fetching NICA, page 26 | Status: 200
# No more data found for NICA at page 26.
# Data for NICA saved to NICA.csv
# Fetching NMB, page 1 | Status: 200
# Fetched page 1 with 50 records for NMB
# Fetching NMB, page 2 | Status: 200
# Fetched page 2 with 50 records for NMB
# Fetching NMB, page 3 | Status: 200
# Fetched page 3 with 50 records for NMB
# Fetching NMB, page 4 | Status: 200
# Fetched page 4 with 50 records for NMB
# Fetching NMB, page 5 | Status: 200
# Fetched page 5 with 50 records for NMB
# Fetching NMB, page 6 | Status: 200
# Fetched page 6 with 50 records for NMB
# Fetching NMB, page 7 | Status: 200
# Fetched page 7 with 50 records for NMB
# Fetching NMB, page 8 | Status: 200
# Fetched page 8 with 50 records for NMB
# Fetching NMB, page 9 | Status: 200
# Fetched page 9 with 50 records for NMB
# Fetching NMB, page 10 | Status: 200
# Fetched page 10 with 50 records for NMB
# Fetching NMB, page 11 | Status: 200
# Fetched page 11 with 50 records for NMB
# Fetching NMB, page 12 | Status: 200
# Fetched page 12 with 50 records for NMB
# Fetching NMB, page 13 | Status: 200
# Fetched page 13 with 50 records for NMB
# Fetching NMB, page 14 | Status: 200
# Fetched page 14 with 50 records for NMB
# Fetching NMB, page 15 | Status: 200
# Fetched page 15 with 50 records for NMB
# Fetching NMB, page 16 | Status: 200
# Fetched page 16 with 50 records for NMB
# Fetching NMB, page 17 | Status: 200
# Fetched page 17 with 50 records for NMB
# Fetching NMB, page 18 | Status: 200
# Fetched page 18 with 50 records for NMB
# Fetching NMB, page 19 | Status: 200
# Fetched page 19 with 50 records for NMB
# Fetching NMB, page 20 | Status: 200
# Fetched page 20 with 50 records for NMB
# Fetching NMB, page 21 | Status: 200
# Fetched page 21 with 50 records for NMB
# Fetching NMB, page 22 | Status: 200
# Fetched page 22 with 50 records for NMB
# Fetching NMB, page 23 | Status: 200
# Fetched page 23 with 50 records for NMB
# Fetching NMB, page 24 | Status: 200
# Fetched page 24 with 50 records for NMB
# Fetching NMB, page 25 | Status: 200
# Fetched page 25 with 1 records for NMB
# Fetching NMB, page 26 | Status: 200
# No more data found for NMB at page 26.
# Data for NMB saved to NMB.csv
# Fetching SBL, page 1 | Status: 200
# Fetched page 1 with 50 records for SBL
# Fetching SBL, page 2 | Status: 200
# Fetched page 2 with 50 records for SBL
# Fetching SBL, page 3 | Status: 200
# Fetched page 3 with 50 records for SBL
# Fetching SBL, page 4 | Status: 200
# Fetched page 4 with 50 records for SBL
# Fetching SBL, page 5 | Status: 200
# Fetched page 5 with 50 records for SBL
# Fetching SBL, page 6 | Status: 200
# Fetched page 6 with 50 records for SBL
# Fetching SBL, page 7 | Status: 200
# Fetched page 7 with 50 records for SBL
# Fetching SBL, page 8 | Status: 200
# Fetched page 8 with 50 records for SBL
# Fetching SBL, page 9 | Status: 200
# Fetched page 9 with 50 records for SBL
# Fetching SBL, page 10 | Status: 200
# Fetched page 10 with 50 records for SBL
# Fetching SBL, page 11 | Status: 200
# Fetched page 11 with 50 records for SBL
# Fetching SBL, page 12 | Status: 200
# Fetched page 12 with 50 records for SBL
# Fetching SBL, page 13 | Status: 200
# Fetched page 13 with 50 records for SBL
# Fetching SBL, page 14 | Status: 200
# Fetched page 14 with 50 records for SBL
# Fetching SBL, page 15 | Status: 200
# Fetched page 15 with 50 records for SBL
# Fetching SBL, page 16 | Status: 200
# Fetched page 16 with 50 records for SBL
# Fetching SBL, page 17 | Status: 200
# Fetched page 17 with 50 records for SBL
# Fetching SBL, page 18 | Status: 200
# Fetched page 18 with 50 records for SBL
# Fetching SBL, page 19 | Status: 200
# Fetched page 19 with 50 records for SBL
# Fetching SBL, page 20 | Status: 200
# Fetched page 20 with 50 records for SBL
# Fetching SBL, page 21 | Status: 200
# Fetched page 21 with 50 records for SBL
# Fetching SBL, page 22 | Status: 200
# Fetched page 22 with 50 records for SBL
# Fetching SBL, page 23 | Status: 200
# Fetched page 23 with 50 records for SBL
# Fetching SBL, page 24 | Status: 200
# Fetched page 24 with 50 records for SBL
# Fetching SBL, page 25 | Status: 200
# Fetched page 25 with 1 records for SBL
# Fetching SBL, page 26 | Status: 200
# No more data found for SBL at page 26.
# Data for SBL saved to SBL.csv
# Fetching LSL, page 1 | Status: 200
# Fetched page 1 with 50 records for LSL
# Fetching LSL, page 2 | Status: 200
# Fetched page 2 with 50 records for LSL
# Fetching LSL, page 3 | Status: 200
# Fetched page 3 with 50 records for LSL
# Fetching LSL, page 4 | Status: 200
# Fetched page 4 with 50 records for LSL
# Fetching LSL, page 5 | Status: 200
# Fetched page 5 with 50 records for LSL
# Fetching LSL, page 6 | Status: 200
# Fetched page 6 with 50 records for LSL
# Fetching LSL, page 7 | Status: 200
# Fetched page 7 with 50 records for LSL
# Fetching LSL, page 8 | Status: 200
# Fetched page 8 with 41 records for LSL
# Fetching LSL, page 9 | Status: 200
# No more data found for LSL at page 9.
# Data for LSL saved to LSL.csv
# Fetching KBL, page 1 | Status: 200
# Fetched page 1 with 50 records for KBL
# Fetching KBL, page 2 | Status: 200
# Fetched page 2 with 50 records for KBL
# Fetching KBL, page 3 | Status: 200
# Fetched page 3 with 50 records for KBL
# Fetching KBL, page 4 | Status: 200
# Fetched page 4 with 50 records for KBL
# Fetching KBL, page 5 | Status: 200
# Fetched page 5 with 50 records for KBL
# Fetching KBL, page 6 | Status: 200
# Fetched page 6 with 50 records for KBL
# Fetching KBL, page 7 | Status: 200
# Fetched page 7 with 50 records for KBL
# Fetching KBL, page 8 | Status: 200
# Fetched page 8 with 50 records for KBL
# Fetching KBL, page 9 | Status: 200
# Fetched page 9 with 50 records for KBL
# Fetching KBL, page 10 | Status: 200
# Fetched page 10 with 50 records for KBL
# Fetching KBL, page 11 | Status: 200
# Fetched page 11 with 50 records for KBL
# Fetching KBL, page 12 | Status: 200
# Fetched page 12 with 50 records for KBL
# Fetching KBL, page 13 | Status: 200
# Fetched page 13 with 50 records for KBL
# Fetching KBL, page 14 | Status: 200
# Fetched page 14 with 50 records for KBL
# Fetching KBL, page 15 | Status: 200
# Fetched page 15 with 50 records for KBL
# Fetching KBL, page 16 | Status: 200
# Fetched page 16 with 50 records for KBL
# Fetching KBL, page 17 | Status: 200
# Fetched page 17 with 50 records for KBL
# Fetching KBL, page 18 | Status: 200
# Fetched page 18 with 50 records for KBL
# Fetching KBL, page 19 | Status: 200
# Fetched page 19 with 50 records for KBL
# Fetching KBL, page 20 | Status: 200
# Fetched page 20 with 50 records for KBL
# Fetching KBL, page 21 | Status: 200
# Fetched page 21 with 50 records for KBL
# Fetching KBL, page 22 | Status: 200
# Fetched page 22 with 50 records for KBL
# Fetching KBL, page 23 | Status: 200
# Fetched page 23 with 50 records for KBL
# Fetching KBL, page 24 | Status: 200
# Fetched page 24 with 10 records for KBL
# Fetching KBL, page 25 | Status: 200
# No more data found for KBL at page 25.
# Data for KBL saved to KBL.csv
# Fetching NBL, page 1 | Status: 200
# Fetched page 1 with 50 records for NBL
# Fetching NBL, page 2 | Status: 200
# Fetched page 2 with 50 records for NBL
# Fetching NBL, page 3 | Status: 200
# Fetched page 3 with 50 records for NBL
# Fetching NBL, page 4 | Status: 200
# Fetched page 4 with 50 records for NBL
# Fetching NBL, page 5 | Status: 200
# Fetched page 5 with 50 records for NBL
# Fetching NBL, page 6 | Status: 200
# Fetched page 6 with 50 records for NBL
# Fetching NBL, page 7 | Status: 200
# Fetched page 7 with 50 records for NBL
# Fetching NBL, page 8 | Status: 200
# Fetched page 8 with 50 records for NBL
# Fetching NBL, page 9 | Status: 200
# Fetched page 9 with 50 records for NBL
# Fetching NBL, page 10 | Status: 200
# Fetched page 10 with 50 records for NBL
# Fetching NBL, page 11 | Status: 200
# Fetched page 11 with 50 records for NBL
# Fetching NBL, page 12 | Status: 200
# Fetched page 12 with 50 records for NBL
# Fetching NBL, page 13 | Status: 200
# Fetched page 13 with 50 records for NBL
# Fetching NBL, page 14 | Status: 200
# Fetched page 14 with 50 records for NBL
# Fetching NBL, page 15 | Status: 200
# Fetched page 15 with 50 records for NBL
# Fetching NBL, page 16 | Status: 200
# Fetched page 16 with 50 records for NBL
# Fetching NBL, page 17 | Status: 200
# Fetched page 17 with 50 records for NBL
# Fetching NBL, page 18 | Status: 200
# Fetched page 18 with 50 records for NBL
# Fetching NBL, page 19 | Status: 200
# Fetched page 19 with 50 records for NBL
# Fetching NBL, page 20 | Status: 200
# Fetched page 20 with 50 records for NBL
# Fetching NBL, page 21 | Status: 200
# Fetched page 21 with 50 records for NBL
# Fetching NBL, page 22 | Status: 200
# Fetched page 22 with 50 records for NBL
# Fetching NBL, page 23 | Status: 200
# Fetched page 23 with 50 records for NBL
# Fetching NBL, page 24 | Status: 200
# Fetched page 24 with 50 records for NBL
# Fetching NBL, page 25 | Status: 200
# Fetched page 25 with 2 records for NBL
# Fetching NBL, page 26 | Status: 200
# No more data found for NBL at page 26.
# Data for NBL saved to NBL.csv
# Fetching PRVU, page 1 | Status: 200
# Fetched page 1 with 50 records for PRVU
# Fetching PRVU, page 2 | Status: 200
# Fetched page 2 with 50 records for PRVU
# Fetching PRVU, page 3 | Status: 200
# Fetched page 3 with 50 records for PRVU
# Fetching PRVU, page 4 | Status: 200
# Fetched page 4 with 50 records for PRVU
# Fetching PRVU, page 5 | Status: 200
# Fetched page 5 with 50 records for PRVU
# Fetching PRVU, page 6 | Status: 200
# Fetched page 6 with 50 records for PRVU
# Fetching PRVU, page 7 | Status: 200
# Fetched page 7 with 50 records for PRVU
# Fetching PRVU, page 8 | Status: 200
# Fetched page 8 with 50 records for PRVU
# Fetching PRVU, page 9 | Status: 200
# Fetched page 9 with 50 records for PRVU
# Fetching PRVU, page 10 | Status: 200
# Fetched page 10 with 50 records for PRVU
# Fetching PRVU, page 11 | Status: 200
# Fetched page 11 with 50 records for PRVU
# Fetching PRVU, page 12 | Status: 200
# Fetched page 12 with 50 records for PRVU
# Fetching PRVU, page 13 | Status: 200
# Fetched page 13 with 50 records for PRVU
# Fetching PRVU, page 14 | Status: 200
# Fetched page 14 with 50 records for PRVU
# Fetching PRVU, page 15 | Status: 200
# Fetched page 15 with 50 records for PRVU
# Fetching PRVU, page 16 | Status: 200
# Fetched page 16 with 50 records for PRVU
# Fetching PRVU, page 17 | Status: 200
# Fetched page 17 with 50 records for PRVU
# Fetching PRVU, page 18 | Status: 200
# Fetched page 18 with 50 records for PRVU
# Fetching PRVU, page 19 | Status: 200
# Fetched page 19 with 50 records for PRVU
# Fetching PRVU, page 20 | Status: 200
# Fetched page 20 with 50 records for PRVU
# Fetching PRVU, page 21 | Status: 200
# Fetched page 21 with 50 records for PRVU
# Fetching PRVU, page 22 | Status: 200
# Fetched page 22 with 50 records for PRVU
# Fetching PRVU, page 23 | Status: 200
# Fetched page 23 with 50 records for PRVU
# Fetching PRVU, page 24 | Status: 200
# Fetched page 24 with 50 records for PRVU
# Fetching PRVU, page 25 | Status: 200
# Fetched page 25 with 2 records for PRVU
# Fetching PRVU, page 26 | Status: 200
# No more data found for PRVU at page 26.
# Data for PRVU saved to PRVU.csv
# Fetching HDL, page 1 | Status: 200
# Fetched page 1 with 50 records for HDL
# Fetching HDL, page 2 | Status: 200
# Fetched page 2 with 50 records for HDL
# Fetching HDL, page 3 | Status: 200
# Fetched page 3 with 50 records for HDL
# Fetching HDL, page 4 | Status: 200
# Fetched page 4 with 50 records for HDL
# Fetching HDL, page 5 | Status: 200
# Fetched page 5 with 50 records for HDL
# Fetching HDL, page 6 | Status: 200
# Fetched page 6 with 50 records for HDL
# Fetching HDL, page 7 | Status: 200
# Fetched page 7 with 50 records for HDL
# Fetching HDL, page 8 | Status: 200
# Fetched page 8 with 50 records for HDL
# Fetching HDL, page 9 | Status: 200
# Fetched page 9 with 50 records for HDL
# Fetching HDL, page 10 | Status: 200
# Fetched page 10 with 50 records for HDL
# Fetching HDL, page 11 | Status: 200
# Fetched page 11 with 50 records for HDL
# Fetching HDL, page 12 | Status: 200
# Fetched page 12 with 50 records for HDL
# Fetching HDL, page 13 | Status: 200
# Fetched page 13 with 50 records for HDL
# Fetching HDL, page 14 | Status: 200
# Fetched page 14 with 50 records for HDL
# Fetching HDL, page 15 | Status: 200
# Fetched page 15 with 50 records for HDL
# Fetching HDL, page 16 | Status: 200
# Fetched page 16 with 50 records for HDL
# Fetching HDL, page 17 | Status: 200
# Fetched page 17 with 50 records for HDL
# Fetching HDL, page 18 | Status: 200
# Fetched page 18 with 50 records for HDL
# Fetching HDL, page 19 | Status: 200
# Fetched page 19 with 50 records for HDL
# Fetching HDL, page 20 | Status: 200
# Fetched page 20 with 50 records for HDL
# Fetching HDL, page 21 | Status: 200
# Fetched page 21 with 50 records for HDL
# Fetching HDL, page 22 | Status: 200
# Fetched page 22 with 50 records for HDL
# Fetching HDL, page 23 | Status: 200
# Fetched page 23 with 50 records for HDL
# Fetching HDL, page 24 | Status: 200
# Fetched page 24 with 50 records for HDL
# Fetching HDL, page 25 | Status: 200
# Fetched page 25 with 1 records for HDL
# Fetching HDL, page 26 | Status: 200
# No more data found for HDL at page 26.
# Data for HDL saved to HDL.csv

# %% [markdown]
# **Question 1**
# # Extact the Price history of ten Commercial banks from given API and save data in .csv format

# %%
import requests
import csv
import time

def fetch_stock_data(symbol, from_date, to_date, items_per_page=50):
    url = "https://www.nepalipaisa.com/api/GetStockHistory"
    page_no = 1
    stock_all_data = []

    while True:
        params = {
            "stockSymbol": symbol,
            "fromDate": from_date,
            "toDate": to_date,
            "pageNo": page_no,
            "itemsPerPage": items_per_page,
            "pagePerDisplay": 10
        }

        response = requests.get(url, params=params)
        print(f"Fetching {symbol}, page {page_no} | Status: {response.status_code}")
        if response.status_code != 200:
            break

        data = response.json()
        stock_data = data.get('result', {}).get('data', [])

        if not stock_data:
            break

        for row in stock_data:
            row['Symbol'] = symbol  # Add symbol to each row
            stock_all_data.append(row)

        page_no += 1
        time.sleep(0.5)

    return stock_all_data

if __name__ == "__main__":
    symbols = ["NMB", "SBL", "KBL", "MBL", "EBL", "SBI", "HBL", "NABIL", "PRVU", "ADBL"]
    from_date = "2020-01-01"
    to_date = "2025-05-19"
    combined_data = []

    for symbol in symbols:
        data = fetch_stock_data(symbol, from_date, to_date)
        combined_data.extend(data)

    if combined_data:
        keys = combined_data[0].keys()
        with open("stockdata.csv", 'w', newline='', encoding='utf-8') as f:
            writer = csv.DictWriter(f, fieldnames=keys)
            writer.writeheader()
            writer.writerows(combined_data)
        print("All stock data saved to stockdata.csv")
# Out:
# Fetching NMB, page 1 | Status: 200
# Fetching NMB, page 2 | Status: 200
# Fetching NMB, page 3 | Status: 200
# Fetching NMB, page 4 | Status: 200
# Fetching NMB, page 5 | Status: 200
# Fetching NMB, page 6 | Status: 200
# Fetching NMB, page 7 | Status: 200
# Fetching NMB, page 8 | Status: 200
# Fetching NMB, page 9 | Status: 200
# Fetching NMB, page 10 | Status: 200
# Fetching NMB, page 11 | Status: 200
# Fetching NMB, page 12 | Status: 200
# Fetching NMB, page 13 | Status: 200
# Fetching NMB, page 14 | Status: 200
# Fetching NMB, page 15 | Status: 200
# Fetching NMB, page 16 | Status: 200
# Fetching NMB, page 17 | Status: 200
# Fetching NMB, page 18 | Status: 200
# Fetching NMB, page 19 | Status: 200
# Fetching NMB, page 20 | Status: 200
# Fetching NMB, page 21 | Status: 200
# Fetching NMB, page 22 | Status: 200
# Fetching NMB, page 23 | Status: 200
# Fetching NMB, page 24 | Status: 200
# Fetching NMB, page 25 | Status: 200
# Fetching NMB, page 26 | Status: 200
# Fetching SBL, page 1 | Status: 200
# Fetching SBL, page 2 | Status: 200
# Fetching SBL, page 3 | Status: 200
# Fetching SBL, page 4 | Status: 200
# Fetching SBL, page 5 | Status: 200
# Fetching SBL, page 6 | Status: 200
# Fetching SBL, page 7 | Status: 200
# Fetching SBL, page 8 | Status: 200
# Fetching SBL, page 9 | Status: 200
# Fetching SBL, page 10 | Status: 200
# Fetching SBL, page 11 | Status: 200
# Fetching SBL, page 12 | Status: 200
# Fetching SBL, page 13 | Status: 200
# Fetching SBL, page 14 | Status: 200
# Fetching SBL, page 15 | Status: 200
# Fetching SBL, page 16 | Status: 200
# Fetching SBL, page 17 | Status: 200
# Fetching SBL, page 18 | Status: 200
# Fetching SBL, page 19 | Status: 200
# Fetching SBL, page 20 | Status: 200
# Fetching SBL, page 21 | Status: 200
# Fetching SBL, page 22 | Status: 200
# Fetching SBL, page 23 | Status: 200
# Fetching SBL, page 24 | Status: 200
# Fetching SBL, page 25 | Status: 200
# Fetching SBL, page 26 | Status: 200
# Fetching KBL, page 1 | Status: 200
# Fetching KBL, page 2 | Status: 200
# Fetching KBL, page 3 | Status: 200
# Fetching KBL, page 4 | Status: 200
# Fetching KBL, page 5 | Status: 200
# Fetching KBL, page 6 | Status: 200
# Fetching KBL, page 7 | Status: 200
# Fetching KBL, page 8 | Status: 200
# Fetching KBL, page 9 | Status: 200
# Fetching KBL, page 10 | Status: 200
# Fetching KBL, page 11 | Status: 200
# Fetching KBL, page 12 | Status: 200
# Fetching KBL, page 13 | Status: 200
# Fetching KBL, page 14 | Status: 200
# Fetching KBL, page 15 | Status: 200
# Fetching KBL, page 16 | Status: 200
# Fetching KBL, page 17 | Status: 200
# Fetching KBL, page 18 | Status: 200
# Fetching KBL, page 19 | Status: 200
# Fetching KBL, page 20 | Status: 200
# Fetching KBL, page 21 | Status: 200
# Fetching KBL, page 22 | Status: 200
# Fetching KBL, page 23 | Status: 200
# Fetching KBL, page 24 | Status: 200
# Fetching KBL, page 25 | Status: 200
# Fetching MBL, page 1 | Status: 200
# Fetching MBL, page 2 | Status: 200
# Fetching MBL, page 3 | Status: 200
# Fetching MBL, page 4 | Status: 200
# Fetching MBL, page 5 | Status: 200
# Fetching MBL, page 6 | Status: 200
# Fetching MBL, page 7 | Status: 200
# Fetching MBL, page 8 | Status: 200
# Fetching MBL, page 9 | Status: 200
# Fetching MBL, page 10 | Status: 200
# Fetching MBL, page 11 | Status: 200
# Fetching MBL, page 12 | Status: 200
# Fetching MBL, page 13 | Status: 200
# Fetching MBL, page 14 | Status: 200
# Fetching MBL, page 15 | Status: 200
# Fetching MBL, page 16 | Status: 200
# Fetching MBL, page 17 | Status: 200
# Fetching MBL, page 18 | Status: 200
# Fetching MBL, page 19 | Status: 200
# Fetching MBL, page 20 | Status: 200
# Fetching MBL, page 21 | Status: 200
# Fetching MBL, page 22 | Status: 200
# Fetching MBL, page 23 | Status: 200
# Fetching MBL, page 24 | Status: 200
# Fetching MBL, page 25 | Status: 200
# Fetching MBL, page 26 | Status: 200
# Fetching EBL, page 1 | Status: 200
# Fetching EBL, page 2 | Status: 200
# Fetching EBL, page 3 | Status: 200
# Fetching EBL, page 4 | Status: 200
# Fetching EBL, page 5 | Status: 200
# Fetching EBL, page 6 | Status: 200
# Fetching EBL, page 7 | Status: 200
# Fetching EBL, page 8 | Status: 200
# Fetching EBL, page 9 | Status: 200
# Fetching EBL, page 10 | Status: 200
# Fetching EBL, page 11 | Status: 200
# Fetching EBL, page 12 | Status: 200
# Fetching EBL, page 13 | Status: 200
# Fetching EBL, page 14 | Status: 200
# Fetching EBL, page 15 | Status: 200
# Fetching EBL, page 16 | Status: 200
# Fetching EBL, page 17 | Status: 200
# Fetching EBL, page 18 | Status: 200
# Fetching EBL, page 19 | Status: 200
# Fetching EBL, page 20 | Status: 200
# Fetching EBL, page 21 | Status: 200
# Fetching EBL, page 22 | Status: 200
# Fetching EBL, page 23 | Status: 200
# Fetching EBL, page 24 | Status: 200
# Fetching EBL, page 25 | Status: 200
# Fetching EBL, page 26 | Status: 200
# Fetching SBI, page 1 | Status: 200
# Fetching SBI, page 2 | Status: 200
# Fetching SBI, page 3 | Status: 200
# Fetching SBI, page 4 | Status: 200
# Fetching SBI, page 5 | Status: 200
# Fetching SBI, page 6 | Status: 200
# Fetching SBI, page 7 | Status: 200
# Fetching SBI, page 8 | Status: 200
# Fetching SBI, page 9 | Status: 200
# Fetching SBI, page 10 | Status: 200
# Fetching SBI, page 11 | Status: 200
# Fetching SBI, page 12 | Status: 200
# Fetching SBI, page 13 | Status: 200
# Fetching SBI, page 14 | Status: 200
# Fetching SBI, page 15 | Status: 200
# Fetching SBI, page 16 | Status: 200
# Fetching SBI, page 17 | Status: 200
# Fetching SBI, page 18 | Status: 200
# Fetching SBI, page 19 | Status: 200
# Fetching SBI, page 20 | Status: 200
# Fetching SBI, page 21 | Status: 200
# Fetching SBI, page 22 | Status: 200
# Fetching SBI, page 23 | Status: 200
# Fetching SBI, page 24 | Status: 200
# Fetching SBI, page 25 | Status: 200
# Fetching SBI, page 26 | Status: 200
# Fetching HBL, page 1 | Status: 200
# Fetching HBL, page 2 | Status: 200
# Fetching HBL, page 3 | Status: 200
# Fetching HBL, page 4 | Status: 200
# Fetching HBL, page 5 | Status: 200
# Fetching HBL, page 6 | Status: 200
# Fetching HBL, page 7 | Status: 200
# Fetching HBL, page 8 | Status: 200
# Fetching HBL, page 9 | Status: 200
# Fetching HBL, page 10 | Status: 200
# Fetching HBL, page 11 | Status: 200
# Fetching HBL, page 12 | Status: 200
# Fetching HBL, page 13 | Status: 200
# Fetching HBL, page 14 | Status: 200
# Fetching HBL, page 15 | Status: 200
# Fetching HBL, page 16 | Status: 200
# Fetching HBL, page 17 | Status: 200
# Fetching HBL, page 18 | Status: 200
# Fetching HBL, page 19 | Status: 200
# Fetching HBL, page 20 | Status: 200
# Fetching HBL, page 21 | Status: 200
# Fetching NABIL, page 1 | Status: 200
# Fetching NABIL, page 2 | Status: 200
# Fetching NABIL, page 3 | Status: 200
# Fetching NABIL, page 4 | Status: 200
# Fetching NABIL, page 5 | Status: 200
# Fetching NABIL, page 6 | Status: 200
# Fetching NABIL, page 7 | Status: 200
# Fetching NABIL, page 8 | Status: 200
# Fetching NABIL, page 9 | Status: 200
# Fetching NABIL, page 10 | Status: 200
# Fetching NABIL, page 11 | Status: 200
# Fetching NABIL, page 12 | Status: 200
# Fetching NABIL, page 13 | Status: 200
# Fetching NABIL, page 14 | Status: 200
# Fetching NABIL, page 15 | Status: 200
# Fetching NABIL, page 16 | Status: 200
# Fetching NABIL, page 17 | Status: 200
# Fetching NABIL, page 18 | Status: 200
# Fetching NABIL, page 19 | Status: 200
# Fetching NABIL, page 20 | Status: 200
# Fetching NABIL, page 21 | Status: 200
# Fetching NABIL, page 22 | Status: 200
# Fetching NABIL, page 23 | Status: 200
# Fetching NABIL, page 24 | Status: 200
# Fetching NABIL, page 25 | Status: 200
# Fetching NABIL, page 26 | Status: 200
# Fetching PRVU, page 1 | Status: 200
# Fetching PRVU, page 2 | Status: 200
# Fetching PRVU, page 3 | Status: 200
# Fetching PRVU, page 4 | Status: 200
# Fetching PRVU, page 5 | Status: 200
# Fetching PRVU, page 6 | Status: 200
# Fetching PRVU, page 7 | Status: 200
# Fetching PRVU, page 8 | Status: 200
# Fetching PRVU, page 9 | Status: 200
# Fetching PRVU, page 10 | Status: 200
# Fetching PRVU, page 11 | Status: 200
# Fetching PRVU, page 12 | Status: 200
# Fetching PRVU, page 13 | Status: 200
# Fetching PRVU, page 14 | Status: 200
# Fetching PRVU, page 15 | Status: 200
# Fetching PRVU, page 16 | Status: 200
# Fetching PRVU, page 17 | Status: 200
# Fetching PRVU, page 18 | Status: 200
# Fetching PRVU, page 19 | Status: 200
# Fetching PRVU, page 20 | Status: 200
# Fetching PRVU, page 21 | Status: 200
# Fetching PRVU, page 22 | Status: 200
# Fetching PRVU, page 23 | Status: 200
# Fetching PRVU, page 24 | Status: 200
# Fetching PRVU, page 25 | Status: 200
# Fetching PRVU, page 26 | Status: 200
# Fetching ADBL, page 1 | Status: 200
# Fetching ADBL, page 2 | Status: 200
# Fetching ADBL, page 3 | Status: 200
# Fetching ADBL, page 4 | Status: 200
# Fetching ADBL, page 5 | Status: 200
# Fetching ADBL, page 6 | Status: 200
# Fetching ADBL, page 7 | Status: 200
# Fetching ADBL, page 8 | Status: 200
# Fetching ADBL, page 9 | Status: 200
# Fetching ADBL, page 10 | Status: 200
# Fetching ADBL, page 11 | Status: 200
# Fetching ADBL, page 12 | Status: 200
# Fetching ADBL, page 13 | Status: 200
# Fetching ADBL, page 14 | Status: 200
# Fetching ADBL, page 15 | Status: 200
# Fetching ADBL, page 16 | Status: 200
# Fetching ADBL, page 17 | Status: 200
# Fetching ADBL, page 18 | Status: 200
# Fetching ADBL, page 19 | Status: 200
# Fetching ADBL, page 20 | Status: 200
# Fetching ADBL, page 21 | Status: 200
# Fetching ADBL, page 22 | Status: 200
# Fetching ADBL, page 23 | Status: 200
# Fetching ADBL, page 24 | Status: 200
# Fetching ADBL, page 25 | Status: 200
# Fetching ADBL, page 26 | Status: 200
# All stock data saved to stockdata.csv

# %% [markdown]
# # Data Clean

# %%
import pandas as pd

df = pd.read_csv("stockdata.csv")
print(df.head())
# Out:
#    sn            tradeDate tradeDateString  maxPrice  minPrice  closingPrice  \
# 0   1  2025-05-19T00:00:00      2025-05-19     239.7     232.5        238.14
# 1   2  2025-05-18T00:00:00      2025-05-18     235.5     232.1        233.63
# 2   3  2025-05-15T00:00:00      2025-05-15     237.0     233.0        234.78
# 3   4  2025-05-14T00:00:00      2025-05-14     237.8     232.0        235.86
# 4   5  2025-05-13T00:00:00      2025-05-13     239.0     235.0        236.36
#
#    noOfTransactions  volume      amount  previousClosing  differenceRs  \
# 0               159   46289  10873278.7           233.63          4.51
# 1               152   23464   5481661.2           234.78         -1.15
# 2               173   50679  11899721.4           235.86         -1.08
# 3               118   16850   3967352.5           236.36         -0.50
# 4               138   32934   7817091.7           238.74         -2.38
#
#    percentChange Symbol
# 0           1.93    NMB
# 1          -0.49    NMB
# 2          -0.46    NMB
# 3          -0.21    NMB
# 4          -1.00    NMB

# %%
df.info()        # Check data types
df.isnull().sum()  # Check for missing values
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11735 entries, 0 to 11734
# Data columns (total 13 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   sn                11735 non-null  int64
#  1   tradeDate         11735 non-null  object
#  2   tradeDateString   11735 non-null  object
#  3   maxPrice          11735 non-null  float64
#  4   minPrice          11735 non-null  float64
#  5   closingPrice      11735 non-null  float64
#  6   noOfTransactions  11735 non-null  int64
#  7   volume            11735 non-null  int64
#  8   amount            11735 non-null  float64
#  9   previousClosing   11735 non-null  float64
#  10  differenceRs      11735 non-null  float64
#  11  percentChange     11735 non-null  float64
#  12  Symbol            11735 non-null  object
# dtypes: float64(7), int64(3), object(3)
# memory usage: 1.2+ MB
# sn                  0
# tradeDate           0
# tradeDateString     0
# maxPrice            0
# minPrice            0
# closingPrice        0
# noOfTransactions    0
# volume              0
# amount              0
# previousClosing     0
# differenceRs        0
# percentChange       0
# Symbol              0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# # 4 Convert the daily to weekly format and plot it.

# %%
df['tradeDateNew'] = pd.to_datetime(df['tradeDateString'])
df.set_index('tradeDateNew', inplace=True)
weekly_df = df.resample('W').agg({'closingPrice': 'last'})
weekly_df.plot(title='Weekly Close Price')
# Out:
# <Axes: title={'center': 'Weekly Close Price'}, xlabel='tradeDateNew'>

# %% [markdown]
# # 5 Convert the data to monthly format and plot it.

# %%
monthly_df = df.resample('ME').agg({'closingPrice': 'last'})
monthly_df.plot(title='Monthly Close Price')
# Out:
# <Axes: title={'center': 'Monthly Close Price'}, xlabel='tradeDateNew'>

# %% [markdown]
# # 6.a. Moving Average

# %%
df['MA_14'] = df['closingPrice'].rolling(window=14).mean()
df[['closingPrice', 'MA_14']].plot(title='14-Day Moving Average')
# Out:
# <Axes: title={'center': '14-Day Moving Average'}, xlabel='tradeDateNew'>

# %% [markdown]
# # 6.b. Weighted Moving Average

# %%
weights = range(1, 15)
def weighted_moving_avg(prices):
    return (prices * weights).sum() / sum(weights)


df['WMA_14'] = df['closingPrice'].rolling(window=14).apply(weighted_moving_avg, raw=True)

df[['closingPrice', 'WMA_14']].plot(title='14-Day Weighted Moving Average')
# Out:
# <Axes: title={'center': '14-Day Weighted Moving Average'}, xlabel='tradeDateNew'>

# %% [markdown]
# # 6.c RSI

# %%
delta = df['closingPrice'].diff()
gain = delta.clip(lower=0)
loss = -delta.clip(upper=0)
avg_gain = gain.rolling(14).mean()
avg_loss = loss.rolling(14).mean()
# Avoid division by zero if avg_loss is 0 or very close to 0
rs = avg_gain / avg_loss
# Handle cases where avg_loss is 0 (RSI would be 100)
rs = rs.replace([float('inf'), -float('inf')], 100)
rs = rs.fillna(0) # Handle cases where both avg_gain and avg_loss are 0
df['RSI'] = 100 - (100 / (1 + rs))
df['RSI'].plot(title='RSI (14)', color='purple')
# Out:
# <Axes: title={'center': 'RSI (14)'}, xlabel='tradeDateNew'>

# %% [markdown]
# # 6.d. OBV

# %%
df['Volume'] = df['volume']
df['OBV'] = 0


price_change = df['closingPrice'].diff()


obv_volume = df['Volume'].where(price_change > 0, -df['Volume'].where(price_change < 0, 0))


if len(df) > 0:
    df['OBV'].iloc[0] = df['Volume'].iloc[0]

    df['OBV'] = obv_volume.cumsum() + df['Volume'].iloc[0] - obv_volume.iloc[0]

if len(df) > 0:
    df['OBV_calc'] = df['Volume']

    df.loc[price_change > 0, 'OBV_calc'] = df['Volume'][price_change > 0] + df['OBV_calc'].shift(1)[price_change > 0]
    df.loc[price_change < 0, 'OBV_calc'] = -df['Volume'][price_change < 0] + df['OBV_calc'].shift(1)[price_change < 0]
    df.loc[price_change == 0, 'OBV_calc'] = df['OBV_calc'].shift(1)[price_change == 0]

    # Handle the very first OBV value explicitly if it wasn't set correctly by the above
    df['OBV_calc'].iloc[0] = df['Volume'].iloc[0]

    # Now set the actual OBV column
    df['OBV'] = df['OBV_calc']
    df = df.drop(columns=['OBV_calc']) # Clean up the temporary column


df['OBV'].plot(title='On-Balance Volume', color='green')
# Out:
# <ipython-input-11-2b755c856ff0>:12: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df['OBV'].iloc[0] = df['Volume'].iloc[0]
# <ipython-input-11-2b755c856ff0>:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['OBV'].iloc[0] = df['Volume'].iloc[0]
# <ipython-input-11-2b755c856ff0>:24: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df['OBV_calc'].iloc[0] = df['Volume'].iloc[0]
# <ipython-input-11-2b755c856ff0>:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['OBV_calc'].iloc[0] = df['Volume'].iloc[0]
# <Axes: title={'center': 'On-Balance Volume'}, xlabel='tradeDateNew'>

# %% [markdown]
# # 6.e. CCI

# %%
tp = (df['maxPrice'] + df['minPrice'] + df['closingPrice']) / 3
tp_ma = tp.rolling(20).mean()
tp_md = (tp - tp_ma).abs().rolling(20).mean()
df['CCI'] = (tp - tp_ma) / (0.015 * tp_md)
df['CCI'].plot(title='CCI (20)', color='orange')
# Out:
# <Axes: title={'center': 'CCI (20)'}, xlabel='tradeDateNew'>
